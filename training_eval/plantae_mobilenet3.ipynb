# %%
#Importing Libraries
import os
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
count = 0 
dirs = os.listdir('data/')
for dir in dirs:
    files = list(os.listdir('data/'+dir))
    print( dir +' Folder has '+ str(len(files)) + ' Images')
    count = count + len(files)
print( 'Images Folder has '+ str(count) + ' Images')
# Out:
# Acorales Folder has 75 Images
# Alismatales Folder has 76 Images
# Apiales Folder has 228 Images
# Arecales Folder has 144 Images
# Asparagales Folder has 111 Images
# Asterales Folder has 95 Images
# Boraginales Folder has 78 Images
# Brassicales Folder has 72 Images
# Caryophyllales Folder has 69 Images
# Commelinales Folder has 70 Images
# Cucurbitales Folder has 93 Images
# Ericales Folder has 80 Images
# Fabales Folder has 58 Images
# Gentianales Folder has 106 Images
# Lamiales Folder has 44 Images
# Laurales Folder has 82 Images
# Magnoliales Folder has 83 Images
# Malpighiales Folder has 70 Images
# Malvales Folder has 58 Images
# Myrtales Folder has 90 Images
# Oxalidales Folder has 79 Images
# Piperales Folder has 92 Images
# Poales Folder has 77 Images
# Ranunculales Folder has 82 Images
# Rosales Folder has 83 Images
# Salviniales Folder has 86 Images
# Sapindales Folder has 85 Images
# Saxifragales Folder has 74 Images
# Solanales Folder has 72 Images
# Zingiberales Folder has 147 Images
# Zygophyllales Folder has 89 Images
# Images Folder has 2748 Images

# %%
# import os
# import cv2
# import imghdr
# import numpy as np

# data_dir = 'data'
# image_exts = ['jpeg', 'jpg', 'png']

# def has_alpha_channel(image_path):
#     img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
#     if img is None:
#         return False
#     # Check if the image has an alpha channel
#     return img.shape[2] == 4 if len(img.shape) == 3 else False

# for image_class in os.listdir(data_dir): 
#     for image in os.listdir(os.path.join(data_dir, image_class)):
#         image_path = os.path.join(data_dir, image_class, image)
#         try: 
#             img = cv2.imread(image_path)
#             tip = imghdr.what(image_path)
#             if tip not in image_exts: 
#                 print('Image not in ext list {}'.format(image_path))
#                 os.remove(image_path)
#             elif has_alpha_channel(image_path):
#                 print('Image has transparency {}'.format(image_path))
#                 os.remove(image_path)
#         except Exception as e: 
#             print('Issue with image {}'.format(image_path))
#             print(e)

# %%
# import os

# def rename_files_in_directory(base_dir):
#     for root, dirs, files in os.walk(base_dir):
#         count = 1
#         for name in files:
#             file_extension = os.path.splitext(name)[1]  # Get file extension
#             new_name = f"{count}{file_extension}"
#             old_path = os.path.join(root, name)
#             new_path = os.path.join(root, new_name)
            
#             if os.path.exists(new_path):
#                 print(f"Skipped renaming {old_path} as {new_path} already exists")
#                 continue
            
#             # Replace non-UTF-8 characters with '_'
#             new_name = ''.join(x if x.isalnum() or x in ('.', '_') else '_' for x in new_name)
            
#             os.rename(old_path, new_path)
#             print(f"Renamed {old_path} to {new_path}")
#             count += 1

# base_dir = r'data/'
# rename_files_in_directory(base_dir)

# %%
base_dir = r'data/'
img_size = 224
batch_size = 32

# %%
import tensorflow as tf

def image_dataset_from_directory_utf8(directory, **kwargs):
    return tf.keras.utils.image_dataset_from_directory(directory, **kwargs)

# Usage
base_dir = r'data'  # Assuming this is your base directory
full_dataset = image_dataset_from_directory_utf8(
    base_dir,
    seed=123,
    image_size=(img_size, img_size),
    batch_size=batch_size
)

# Get class names
class_names = full_dataset.class_names

# Calculate the number of batches
num_batches = len(full_dataset)
num_train = int(0.7 * num_batches)
num_val = int(0.1 * num_batches)
num_test = num_batches - num_train - num_val

# Split the dataset into train, validation, and test datasets
train_ds = full_dataset.take(num_train)
temp_ds = full_dataset.skip(num_train)
val_ds = temp_ds.take(num_val)
test_ds = temp_ds.skip(num_val)

# Print the sizes of each dataset
print("Train dataset size:", len(train_ds))
print("Validation dataset size:", len(val_ds))
print("Test dataset size:", len(test_ds))
# Out:
# Found 2748 files belonging to 31 classes.
# Train dataset size: 60
# Validation dataset size: 8
# Test dataset size: 18

# %%
order_names = full_dataset.class_names
order_names
# Out:
# ['Acorales',
#  'Alismatales',
#  'Apiales',
#  'Arecales',
#  'Asparagales',
#  'Asterales',
#  'Boraginales',
#  'Brassicales',
#  'Caryophyllales',
#  'Commelinales',
#  'Cucurbitales',
#  'Ericales',
#  'Fabales',
#  'Gentianales',
#  'Lamiales',
#  'Laurales',
#  'Magnoliales',
#  'Malpighiales',
#  'Malvales',
#  'Myrtales',
#  'Oxalidales',
#  'Piperales',
#  'Poales',
#  'Ranunculales',
#  'Rosales',
#  'Salviniales',
#  'Sapindales',
#  'Saxifragales',
#  'Solanales',
#  'Zingiberales',
#  'Zygophyllales']

# %%
import matplotlib.pyplot as plt

i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3,3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(order_names[labels[i]])
        plt.axis('off')

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %%
data_augmentation = Sequential([
    layers.RandomFlip("horizontal", input_shape = (224,224,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        images = data_augmentation(images)
        plt.subplot(3,3, i+1)
        plt.imshow(images[0].numpy().astype('uint8'))
        plt.axis('off')

# %%
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.optimizers import Adam

base_model = MobileNetV3Large(input_shape=(224, 224, 3),
                         include_top=False,
                         weights='imagenet')

base_model.trainable = False

model = Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(31)
])

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Function  (None, 7, 7, 960)         2996352
#  al)
#
#  global_average_pooling2d (  (None, 960)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               123008
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 31)                3999
#
# =================================================================
# Total params: 3123359 (11.91 MB)
# Trainable params: 127007 (496.12 KB)
# Non-trainable params: 2996352 (11.43 MB)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(factor=0.2, patience=3)

history = model.fit(train_ds,
                    epochs=100,
                    validation_data=val_ds,
                    callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 60/60 [==============================] - 106s 1s/step - loss: 3.7810 - accuracy: 0.0526 - val_loss: 3.3935 - val_accuracy: 0.1484 - lr: 1.0000e-04
# Epoch 2/100
# 60/60 [==============================] - 76s 1s/step - loss: 3.3448 - accuracy: 0.1104 - val_loss: 3.1483 - val_accuracy: 0.2461 - lr: 1.0000e-04
# Epoch 3/100
# 60/60 [==============================] - 76s 1s/step - loss: 3.1112 - accuracy: 0.1896 - val_loss: 2.9742 - val_accuracy: 0.2812 - lr: 1.0000e-04
# Epoch 4/100
# 60/60 [==============================] - 74s 1s/step - loss: 2.9316 - accuracy: 0.2443 - val_loss: 2.8456 - val_accuracy: 0.3008 - lr: 1.0000e-04
# Epoch 5/100
# 60/60 [==============================] - 77s 1s/step - loss: 2.7955 - accuracy: 0.2698 - val_loss: 2.7245 - val_accuracy: 0.3320 - lr: 1.0000e-04
# Epoch 6/100
# 60/60 [==============================] - 76s 1s/step - loss: 2.6622 - accuracy: 0.3078 - val_loss: 2.6206 - val_accuracy: 0.3594 - lr: 1.0000e-04
# Epoch 7/100
# 60/60 [==============================] - 76s 1s/step - loss: 2.5357 - accuracy: 0.3380 - val_loss: 2.5225 - val_accuracy: 0.3555 - lr: 1.0000e-04
# Epoch 8/100
# 60/60 [==============================] - 75s 1s/step - loss: 2.4082 - accuracy: 0.3786 - val_loss: 2.4312 - val_accuracy: 0.3789 - lr: 1.0000e-04
# Epoch 9/100
# 60/60 [==============================] - 78s 1s/step - loss: 2.3190 - accuracy: 0.3786 - val_loss: 2.3505 - val_accuracy: 0.4062 - lr: 1.0000e-04
# Epoch 10/100
# 60/60 [==============================] - 75s 1s/step - loss: 2.2045 - accuracy: 0.4198 - val_loss: 2.2824 - val_accuracy: 0.4141 - lr: 1.0000e-04
# Epoch 11/100
# 60/60 [==============================] - 75s 1s/step - loss: 2.1233 - accuracy: 0.4391 - val_loss: 2.2166 - val_accuracy: 0.4375 - lr: 1.0000e-04
# Epoch 12/100
# 60/60 [==============================] - 79s 1s/step - loss: 2.0486 - accuracy: 0.4635 - val_loss: 2.1631 - val_accuracy: 0.4492 - lr: 1.0000e-04
# Epoch 13/100
# 60/60 [==============================] - 77s 1s/step - loss: 1.9693 - accuracy: 0.4755 - val_loss: 2.1164 - val_accuracy: 0.4648 - lr: 1.0000e-04
# Epoch 14/100
# 60/60 [==============================] - 77s 1s/step - loss: 1.9013 - accuracy: 0.5099 - val_loss: 2.0618 - val_accuracy: 0.4883 - lr: 1.0000e-04
# Epoch 15/100
# 60/60 [==============================] - 79s 1s/step - loss: 1.8618 - accuracy: 0.5016 - val_loss: 2.0198 - val_accuracy: 0.4844 - lr: 1.0000e-04
# Epoch 16/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.7804 - accuracy: 0.5307 - val_loss: 1.9770 - val_accuracy: 0.4883 - lr: 1.0000e-04
# Epoch 17/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.7106 - accuracy: 0.5604 - val_loss: 1.9502 - val_accuracy: 0.4883 - lr: 1.0000e-04
# Epoch 18/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.6742 - accuracy: 0.5641 - val_loss: 1.9220 - val_accuracy: 0.4961 - lr: 1.0000e-04
# Epoch 19/100
# 60/60 [==============================] - 78s 1s/step - loss: 1.6057 - accuracy: 0.5802 - val_loss: 1.8880 - val_accuracy: 0.4922 - lr: 1.0000e-04
# Epoch 20/100
# 60/60 [==============================] - 79s 1s/step - loss: 1.5782 - accuracy: 0.5880 - val_loss: 1.8649 - val_accuracy: 0.4961 - lr: 1.0000e-04
# Epoch 21/100
# 60/60 [==============================] - 78s 1s/step - loss: 1.5284 - accuracy: 0.6068 - val_loss: 1.8411 - val_accuracy: 0.4961 - lr: 1.0000e-04
# Epoch 22/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.4830 - accuracy: 0.6089 - val_loss: 1.8175 - val_accuracy: 0.5195 - lr: 1.0000e-04
# Epoch 23/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.4743 - accuracy: 0.6156 - val_loss: 1.8019 - val_accuracy: 0.5312 - lr: 1.0000e-04
# Epoch 24/100
# 60/60 [==============================] - 79s 1s/step - loss: 1.3965 - accuracy: 0.6391 - val_loss: 1.7851 - val_accuracy: 0.5508 - lr: 1.0000e-04
# Epoch 25/100
# 60/60 [==============================] - 79s 1s/step - loss: 1.3703 - accuracy: 0.6510 - val_loss: 1.7577 - val_accuracy: 0.5547 - lr: 1.0000e-04
# Epoch 26/100
# 60/60 [==============================] - 77s 1s/step - loss: 1.3414 - accuracy: 0.6479 - val_loss: 1.7506 - val_accuracy: 0.5391 - lr: 1.0000e-04
# Epoch 27/100
# 60/60 [==============================] - 79s 1s/step - loss: 1.2905 - accuracy: 0.6609 - val_loss: 1.7265 - val_accuracy: 0.5508 - lr: 1.0000e-04
# Epoch 28/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.2497 - accuracy: 0.6818 - val_loss: 1.7140 - val_accuracy: 0.5508 - lr: 1.0000e-04
# Epoch 29/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.2067 - accuracy: 0.7104 - val_loss: 1.6999 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 30/100
# 60/60 [==============================] - 79s 1s/step - loss: 1.1837 - accuracy: 0.7089 - val_loss: 1.6914 - val_accuracy: 0.5586 - lr: 1.0000e-04
# Epoch 31/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.1437 - accuracy: 0.7125 - val_loss: 1.6742 - val_accuracy: 0.5664 - lr: 1.0000e-04
# Epoch 32/100
# 60/60 [==============================] - 81s 1s/step - loss: 1.1283 - accuracy: 0.7161 - val_loss: 1.6632 - val_accuracy: 0.5664 - lr: 1.0000e-04
# Epoch 33/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.0847 - accuracy: 0.7370 - val_loss: 1.6499 - val_accuracy: 0.5742 - lr: 1.0000e-04
# Epoch 34/100
# 60/60 [==============================] - 80s 1s/step - loss: 1.0610 - accuracy: 0.7323 - val_loss: 1.6352 - val_accuracy: 0.5703 - lr: 1.0000e-04
# Epoch 35/100
# 60/60 [==============================] - 83s 1s/step - loss: 1.0345 - accuracy: 0.7474 - val_loss: 1.6273 - val_accuracy: 0.5742 - lr: 1.0000e-04
# Epoch 36/100
# 60/60 [==============================] - 85s 1s/step - loss: 1.0221 - accuracy: 0.7495 - val_loss: 1.6141 - val_accuracy: 0.5938 - lr: 1.0000e-04
# Epoch 37/100
# 60/60 [==============================] - 81s 1s/step - loss: 0.9943 - accuracy: 0.7651 - val_loss: 1.6048 - val_accuracy: 0.5977 - lr: 1.0000e-04
# Epoch 38/100
# 60/60 [==============================] - 79s 1s/step - loss: 0.9470 - accuracy: 0.7698 - val_loss: 1.5960 - val_accuracy: 0.5938 - lr: 1.0000e-04
# Epoch 39/100
# 60/60 [==============================] - 80s 1s/step - loss: 0.9461 - accuracy: 0.7870 - val_loss: 1.5843 - val_accuracy: 0.5938 - lr: 1.0000e-04
# Epoch 40/100
# 60/60 [==============================] - 80s 1s/step - loss: 0.9092 - accuracy: 0.7896 - val_loss: 1.5804 - val_accuracy: 0.5859 - lr: 1.0000e-04
# Epoch 41/100
# 60/60 [==============================] - 73s 1s/step - loss: 0.8816 - accuracy: 0.7943 - val_loss: 1.5689 - val_accuracy: 0.5977 - lr: 1.0000e-04
# Epoch 42/100
# 60/60 [==============================] - 73s 1s/step - loss: 0.8626 - accuracy: 0.7969 - val_loss: 1.5554 - val_accuracy: 0.6016 - lr: 1.0000e-04
# Epoch 43/100
# 60/60 [==============================] - 73s 1s/step - loss: 0.8433 - accuracy: 0.7995 - val_loss: 1.5515 - val_accuracy: 0.6094 - lr: 1.0000e-04
# Epoch 44/100
# 60/60 [==============================] - 78s 1s/step - loss: 0.8236 - accuracy: 0.8198 - val_loss: 1.5394 - val_accuracy: 0.6211 - lr: 1.0000e-04
# Epoch 45/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.8020 - accuracy: 0.8198 - val_loss: 1.5303 - val_accuracy: 0.6211 - lr: 1.0000e-04
# Epoch 46/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.7895 - accuracy: 0.8167 - val_loss: 1.5273 - val_accuracy: 0.6211 - lr: 1.0000e-04
# Epoch 47/100
# 60/60 [==============================] - 82s 1s/step - loss: 0.7859 - accuracy: 0.8146 - val_loss: 1.5214 - val_accuracy: 0.6211 - lr: 1.0000e-04
# Epoch 48/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.7472 - accuracy: 0.8266 - val_loss: 1.5218 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 49/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.7374 - accuracy: 0.8318 - val_loss: 1.5147 - val_accuracy: 0.6289 - lr: 1.0000e-04
# Epoch 50/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.6932 - accuracy: 0.8578 - val_loss: 1.5095 - val_accuracy: 0.6367 - lr: 1.0000e-04
# Epoch 51/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.6996 - accuracy: 0.8458 - val_loss: 1.5000 - val_accuracy: 0.6211 - lr: 1.0000e-04
# Epoch 52/100
# 60/60 [==============================] - 82s 1s/step - loss: 0.6594 - accuracy: 0.8703 - val_loss: 1.4966 - val_accuracy: 0.6328 - lr: 1.0000e-04
# Epoch 53/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.6314 - accuracy: 0.8708 - val_loss: 1.4862 - val_accuracy: 0.6367 - lr: 1.0000e-04
# Epoch 54/100
# 60/60 [==============================] - 82s 1s/step - loss: 0.6300 - accuracy: 0.8609 - val_loss: 1.4887 - val_accuracy: 0.6328 - lr: 1.0000e-04
# Epoch 55/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.6312 - accuracy: 0.8646 - val_loss: 1.4857 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 56/100
# 60/60 [==============================] - 82s 1s/step - loss: 0.6227 - accuracy: 0.8661 - val_loss: 1.4830 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 57/100
# 60/60 [==============================] - 82s 1s/step - loss: 0.5781 - accuracy: 0.8792 - val_loss: 1.4770 - val_accuracy: 0.6367 - lr: 1.0000e-04
# Epoch 58/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.5761 - accuracy: 0.8818 - val_loss: 1.4707 - val_accuracy: 0.6367 - lr: 1.0000e-04
# Epoch 59/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.5675 - accuracy: 0.8859 - val_loss: 1.4652 - val_accuracy: 0.6484 - lr: 1.0000e-04
# Epoch 60/100
# 60/60 [==============================] - 82s 1s/step - loss: 0.5468 - accuracy: 0.8885 - val_loss: 1.4603 - val_accuracy: 0.6445 - lr: 1.0000e-04
# Epoch 61/100
# 60/60 [==============================] - 78s 1s/step - loss: 0.5399 - accuracy: 0.8844 - val_loss: 1.4533 - val_accuracy: 0.6484 - lr: 1.0000e-04
# Epoch 62/100
# 60/60 [==============================] - 81s 1s/step - loss: 0.5253 - accuracy: 0.8943 - val_loss: 1.4575 - val_accuracy: 0.6406 - lr: 1.0000e-04
# Epoch 63/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.5236 - accuracy: 0.8958 - val_loss: 1.4559 - val_accuracy: 0.6523 - lr: 1.0000e-04
# Epoch 64/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.5062 - accuracy: 0.9042 - val_loss: 1.4536 - val_accuracy: 0.6484 - lr: 1.0000e-04
# Epoch 65/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.4842 - accuracy: 0.9125 - val_loss: 1.4518 - val_accuracy: 0.6523 - lr: 2.0000e-05
# Epoch 66/100
# 60/60 [==============================] - 85s 1s/step - loss: 0.4646 - accuracy: 0.9193 - val_loss: 1.4498 - val_accuracy: 0.6602 - lr: 2.0000e-05
# Epoch 67/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.4880 - accuracy: 0.9021 - val_loss: 1.4490 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 68/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.4898 - accuracy: 0.8969 - val_loss: 1.4478 - val_accuracy: 0.6602 - lr: 2.0000e-05
# Epoch 69/100
# 60/60 [==============================] - 83s 1s/step - loss: 0.4730 - accuracy: 0.9125 - val_loss: 1.4481 - val_accuracy: 0.6602 - lr: 2.0000e-05
# Epoch 70/100
# 60/60 [==============================] - 85s 1s/step - loss: 0.4673 - accuracy: 0.9135 - val_loss: 1.4477 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 71/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.4684 - accuracy: 0.9115 - val_loss: 1.4472 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 72/100
# 60/60 [==============================] - 87s 1s/step - loss: 0.4743 - accuracy: 0.9135 - val_loss: 1.4444 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 73/100
# 60/60 [==============================] - 86s 1s/step - loss: 0.4649 - accuracy: 0.9161 - val_loss: 1.4443 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 74/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.4656 - accuracy: 0.9151 - val_loss: 1.4444 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 75/100
# 60/60 [==============================] - 85s 1s/step - loss: 0.4546 - accuracy: 0.9182 - val_loss: 1.4440 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 76/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.4608 - accuracy: 0.9167 - val_loss: 1.4447 - val_accuracy: 0.6602 - lr: 2.0000e-05
# Epoch 77/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.4508 - accuracy: 0.9214 - val_loss: 1.4443 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 78/100
# 60/60 [==============================] - 85s 1s/step - loss: 0.4578 - accuracy: 0.9135 - val_loss: 1.4447 - val_accuracy: 0.6562 - lr: 2.0000e-05
# Epoch 79/100
# 60/60 [==============================] - 85s 1s/step - loss: 0.4455 - accuracy: 0.9266 - val_loss: 1.4441 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 80/100
# 60/60 [==============================] - 85s 1s/step - loss: 0.4515 - accuracy: 0.9167 - val_loss: 1.4438 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 81/100
# 60/60 [==============================] - 86s 1s/step - loss: 0.4405 - accuracy: 0.9182 - val_loss: 1.4435 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 82/100
# 60/60 [==============================] - 82s 1s/step - loss: 0.4430 - accuracy: 0.9161 - val_loss: 1.4433 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 83/100
# 60/60 [==============================] - 80s 1s/step - loss: 0.4504 - accuracy: 0.9167 - val_loss: 1.4433 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 84/100
# 60/60 [==============================] - 80s 1s/step - loss: 0.4554 - accuracy: 0.9151 - val_loss: 1.4432 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 85/100
# 60/60 [==============================] - 80s 1s/step - loss: 0.4529 - accuracy: 0.9167 - val_loss: 1.4428 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 86/100
# 60/60 [==============================] - 80s 1s/step - loss: 0.4430 - accuracy: 0.9161 - val_loss: 1.4426 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 87/100
# 60/60 [==============================] - 82s 1s/step - loss: 0.4540 - accuracy: 0.9187 - val_loss: 1.4425 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 88/100
# 60/60 [==============================] - 84s 1s/step - loss: 0.4449 - accuracy: 0.9198 - val_loss: 1.4424 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 89/100
# 60/60 [==============================] - 85s 1s/step - loss: 0.4442 - accuracy: 0.9161 - val_loss: 1.4425 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 90/100
# 60/60 [==============================] - 85s 1s/step - loss: 0.4459 - accuracy: 0.9214 - val_loss: 1.4422 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 91/100
# 60/60 [==============================] - 86s 1s/step - loss: 0.4483 - accuracy: 0.9219 - val_loss: 1.4425 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 92/100
# 60/60 [==============================] - 86s 1s/step - loss: 0.4520 - accuracy: 0.9172 - val_loss: 1.4424 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 93/100
# 60/60 [==============================] - 86s 1s/step - loss: 0.4403 - accuracy: 0.9193 - val_loss: 1.4424 - val_accuracy: 0.6562 - lr: 4.0000e-06
# Epoch 94/100
# 60/60 [==============================] - 89s 1s/step - loss: 0.4409 - accuracy: 0.9260 - val_loss: 1.4424 - val_accuracy: 0.6562 - lr: 8.0000e-07
# Epoch 95/100
# 60/60 [==============================] - 87s 1s/step - loss: 0.4343 - accuracy: 0.9240 - val_loss: 1.4425 - val_accuracy: 0.6562 - lr: 8.0000e-07

# %%
test_pred = model.predict(test_ds)
test_pred = np.argmax(test_pred, axis=1)

test_labels = np.concatenate([y for x, y in test_ds], axis=0)
# Out:
# 18/18 [==============================] - 60s 2s/step

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(test_labels, test_pred)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 18/18 [==============================] - 51s 1s/step - loss: 1.8536 - accuracy: 0.5612
# Test Loss: 1.8536020517349243
# Test Accuracy: 0.561188817024231

# %%
y_true = []
y_pred = []

# %%
for images, labels in test_ds:
    predictions = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(tf.argmax(predictions, axis=1).numpy())

# Generate classification report
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 8s 8s/step
#                 precision    recall  f1-score   support
#
#       Acorales       0.58      0.61      0.59        18
#    Alismatales       0.55      0.38      0.44        16
#        Apiales       0.55      0.74      0.63        43
#       Arecales       0.71      0.79      0.75        34
#    Asparagales       0.62      0.43      0.51        23
#      Asterales       0.48      0.71      0.57        14
#    Boraginales       0.56      0.36      0.43        14
#    Brassicales       0.73      0.52      0.61        21
# Caryophyllales       0.43      0.35      0.39        17
#   Commelinales       0.50      0.62      0.56         8
#   Cucurbitales       0.62      0.57      0.59        14
#       Ericales       0.45      0.26      0.33        19
#        Fabales       0.50      0.33      0.40        15
#    Gentianales       0.50      0.39      0.44        23
#       Lamiales       0.67      0.31      0.42        13
#       Laurales       0.15      0.12      0.14        16
#    Magnoliales       0.58      0.64      0.61        22
#   Malpighiales       0.16      0.33      0.21         9
#       Malvales       0.39      0.54      0.45        13
#       Myrtales       0.44      0.47      0.46        17
#     Oxalidales       0.40      0.36      0.38        11
#      Piperales       0.64      0.80      0.71        20
#         Poales       0.80      0.50      0.62        24
#   Ranunculales       0.32      0.39      0.35        18
#        Rosales       0.30      0.33      0.32        18
#    Salviniales       0.86      0.86      0.86        14
#     Sapindales       0.35      0.50      0.41        14
#   Saxifragales       0.37      0.39      0.38        18
#      Solanales       0.20      0.09      0.13        11
#   Zingiberales       0.79      1.00      0.88        33
#  Zygophyllales       0.58      0.50      0.54        22
#
#       accuracy                           0.53       572
#      macro avg       0.51      0.49      0.49       572
#   weighted avg       0.54      0.53      0.52       572

# %%
model.save('models/plantae_mobilenet3.h5')
# Out:
# c:\Users\Ate Sheesha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def classify_images(image_path):
    input_image = tf.keras.utils.load_img(image_path, target_size=(224, 224))
    input_image_array = tf.keras.utils.img_to_array(input_image)
    input_image_exp_dim = tf.expand_dims(input_image_array, 0)

    predictions = model.predict(input_image_exp_dim)
    result = tf.nn.softmax(predictions[0]).numpy()  # Convert tensor to NumPy array
    
    # Get the top 3 predictions
    top_3_indices = np.argsort(result)[-4:][::-1]
    top_3_scores = result[top_3_indices]
    
    outcome = "Top 3 matches:\n"
    for i in range(3):
        outcome += f"{i+1}. {order_names[top_3_indices[i]]} with a score of {top_3_scores[i] * 100:.2f}%\n"
    
    return outcome

# %%
print(classify_images('alismatales.png'))
# Out:
# 1/1 [==============================] - 0s 180ms/step
# Top 3 matches:
# 1. Acorales with a score of 36.18%
# 2. Alismatales with a score of 28.61%
# 3. Arecales with a score of 6.51%

# %%
print(classify_images('commelinales.png'))
# Out:
# 1/1 [==============================] - 0s 141ms/step
# Top 3 matches:
# 1. Commelinales with a score of 90.37%
# 2. Ranunculales with a score of 2.41%
# 3. Malvales with a score of 1.21%
